# %% [markdown]
# RUN THE COMMAND BELOW FIRST TO INSTALL pytesseract.

# %%
import cv2
import urllib.request
import numpy as np
from PIL import Image
from google.colab.patches import cv2_imshow

image_url = "https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fst.hotrod.com%2Fuploads%2Fsites%2F21%2F2015%2F07%2Fpersonalized-license-plates-from-mustang-week-2015-34.jpg&f=1&nofb=1&ipt=b1bada87dcb13ef6db54f2ae496157cc8410b99d36ac5bf7f16babfdcdf34f01"
image_name = "license_plate.jpg"
urllib.request.urlretrieve(image_url, image_name)

input_size = (320, 320)

image = cv2.imread(image_name)
image = cv2.resize(image, input_size)
annotated_image = image.copy()

east_detector
db50_detector = cv2.dnn_TextDetectionModel_DB("DB_TD500_resnet50.onnx")
db18_detector = cv2.dnn_TextDetectionModel_DB("DB_TD500_resnet50.onnx")

cv2_imshow(annotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>
